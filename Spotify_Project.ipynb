# %% [markdown]
# <a href="https://colab.research.google.com/github/Prudhvim03/Spotify-Data-Pipeline-Project/blob/main/Spotify_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /usr/local/lib/python3.11/dist-packages (2.25.0)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.11/dist-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.11/dist-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from spotipy) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->spotipy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->spotipy) (2025.1.31)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = "", client_secret = "")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/1YUVG3tWJL8bYRpNiRFd29"

# %%
playlist_uri = playlist_link.split("/")[-1].split("?")[0]

# %%
print(playlist_uri)
# Out:
# 1YUVG3tWJL8bYRpNiRFd29

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data['items']
# Out:
# [{'added_at': '2019-11-01T13:14:52Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/3rpmVMH5kV6jYkzSmlpn5u',
#     'id': '3rpmVMH5kV6jYkzSmlpn5u',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dc3f0e7ab81ade4bd20ab217',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dc3f0e7ab81ade4bd20ab217',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dc3f0e7ab81ade4bd20ab217',
#       'width': 64}],
#     'name': 'Rangam',
#     'release_date': '2011-04-09',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:3rpmVMH5kV6jYkzSmlpn5u',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#       'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#       'id': '29aw5YCdIw2FEXYyAJZI8l',
#       'name': 'Harris Jayaraj',
#       'type': 'artist',
#       'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3rpmVMH5kV6jYkzSmlpn5u'},
#     'total_tracks': 6},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qcMtXmofIpnR9TBhgamMR'},
#      'href': 'https://api.spotify.com/v1/artists/6qcMtXmofIpnR9TBhgamMR',
#      'id': '6qcMtXmofIpnR9TBhgamMR',
#      'name': 'Aalaap Raju',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qcMtXmofIpnR9TBhgamMR'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1EAoBVsvTYarQhO6i9zAG9'},
#      'href': 'https://api.spotify.com/v1/artists/1EAoBVsvTYarQhO6i9zAG9',
#      'id': '1EAoBVsvTYarQhO6i9zAG9',
#      'name': 'Prasanthini',
#      'type': 'artist',
#      'uri': 'spotify:artist:1EAoBVsvTYarQhO6i9zAG9'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 330505,
#    'external_ids': {'isrc': 'INA091112832'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Yqw4HtJuFXleJtgzYXWzT'},
#    'href': 'https://api.spotify.com/v1/tracks/6Yqw4HtJuFXleJtgzYXWzT',
#    'id': '6Yqw4HtJuFXleJtgzYXWzT',
#    'name': 'Endhuko Emo',
#    'popularity': 59,
#    'uri': 'spotify:track:6Yqw4HtJuFXleJtgzYXWzT',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-11-01T13:17:31Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6LDkuQZTLwRVja4CpYOCuu',
#     'id': '6LDkuQZTLwRVja4CpYOCuu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273752df54cdb73daae0a00950e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02752df54cdb73daae0a00950e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851752df54cdb73daae0a00950e',
#       'width': 64}],
#     'name': 'Beauty & The Beats of Samantha',
#     'release_date': '2019-04-26',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6LDkuQZTLwRVja4CpYOCuu',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xlqU0G9EloUPHL1qlmWY6'},
#       'href': 'https://api.spotify.com/v1/artists/4xlqU0G9EloUPHL1qlmWY6',
#       'id': '4xlqU0G9EloUPHL1qlmWY6',
#       'name': 'Gopi Sundar',
#       'type': 'artist',
#       'uri': 'spotify:artist:4xlqU0G9EloUPHL1qlmWY6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6LDkuQZTLwRVja4CpYOCuu'},
#     'total_tracks': 18},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2WF7juQ5oilpZCqikRtP'},
#      'href': 'https://api.spotify.com/v1/artists/5a2WF7juQ5oilpZCqikRtP',
#      'id': '5a2WF7juQ5oilpZCqikRtP',
#      'name': 'Rahul Nambiar',
#      'type': 'artist',
#      'uri': 'spotify:artist:5a2WF7juQ5oilpZCqikRtP'}],
#    'disc_number': 1,
#    'track_number': 15,
#    'duration_ms': 262246,
#    'external_ids': {'isrc': 'INA091113014'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3ydF3JegxOkpoVy9gIfpXC'},
#    'href': 'https://api.spotify.com/v1/tracks/3ydF3JegxOkpoVy9gIfpXC',
#    'id': '3ydF3JegxOkpoVy9gIfpXC',
#    'name': 'Guruvaram',
#    'popularity': 27,
#    'uri': 'spotify:track:3ydF3JegxOkpoVy9gIfpXC',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-11-01T13:17:41Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/0U9GjYJr2K1CK8tOax7Hrf',
#     'id': '0U9GjYJr2K1CK8tOax7Hrf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27373615189b81bfd6bba3f4dab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0273615189b81bfd6bba3f4dab',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485173615189b81bfd6bba3f4dab',
#       'width': 64}],
#     'name': 'Mirchi',
#     'release_date': '2013-01-05',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0U9GjYJr2K1CK8tOax7Hrf',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#       'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#       'id': '5sSzCxHtgL82pYDvx2QyEU',
#       'name': 'Devi Sri Prasad',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0U9GjYJr2K1CK8tOax7Hrf'},
#     'total_tracks': 7},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4iA6bUhiZyvRKJf4FNVX39'},
#      'href': 'https://api.spotify.com/v1/artists/4iA6bUhiZyvRKJf4FNVX39',
#      'id': '4iA6bUhiZyvRKJf4FNVX39',
#      'name': 'Vijay Prakash',
#      'type': 'artist',
#      'uri': 'spotify:artist:4iA6bUhiZyvRKJf4FNVX39'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0vWyMSeg4ixQ98Srb8E4y5'},
#      'href': 'https://api.spotify.com/v1/artists/0vWyMSeg4ixQ98Srb8E4y5',
#      'id': '0vWyMSeg4ixQ98Srb8E4y5',
#      'name': 'Anitha Karthikeyan',
#      'type': 'artist',
#      'uri': 'spotify:artist:0vWyMSeg4ixQ98Srb8E4y5'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 266760,
#    'external_ids': {'isrc': 'INA091213855'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4AuRsGcSsNqslLywUCWhAG'},
#    'href': 'https://api.spotify.com/v1/tracks/4AuRsGcSsNqslLywUCWhAG',
#    'id': '4AuRsGcSsNqslLywUCWhAG',
#    'name': 'Idhedho Bagundhe',
#    'popularity': 59,
#    'uri': 'spotify:track:4AuRsGcSsNqslLywUCWhAG',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-11-01T13:21:57Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/7vuWNVdv7zSwgHJ7qx26O4',
#     'id': '7vuWNVdv7zSwgHJ7qx26O4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738335d4c9f1240433714f0a33',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028335d4c9f1240433714f0a33',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518335d4c9f1240433714f0a33',
#       'width': 64}],
#     'name': 'Aarya - 2 (Original Motion Picture Soundtrack)',
#     'release_date': '2009-10-30',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:7vuWNVdv7zSwgHJ7qx26O4',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#       'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#       'id': '5sSzCxHtgL82pYDvx2QyEU',
#       'name': 'Devi Sri Prasad',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7vuWNVdv7zSwgHJ7qx26O4'},
#     'total_tracks': 8},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#      'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#      'id': '5sSzCxHtgL82pYDvx2QyEU',
#      'name': 'Devi Sri Prasad',
#      'type': 'artist',
#      'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4fEkbug6kZzzJ8eYX6Kbbp'},
#      'href': 'https://api.spotify.com/v1/artists/4fEkbug6kZzzJ8eYX6Kbbp',
#      'id': '4fEkbug6kZzzJ8eYX6Kbbp',
#      'name': 'KK',
#      'type': 'artist',
#      'uri': 'spotify:artist:4fEkbug6kZzzJ8eYX6Kbbp'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 327640,
#    'external_ids': {'isrc': 'INS170900435'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/57zEYntUat0ofbFpoicN26'},
#    'href': 'https://api.spotify.com/v1/tracks/57zEYntUat0ofbFpoicN26',
#    'id': '57zEYntUat0ofbFpoicN26',
#    'name': 'Uppenantha',
#    'popularity': 64,
#    'uri': 'spotify:track:57zEYntUat0ofbFpoicN26',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-11-01T13:28:38Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'compilation',
#     'href': 'https://api.spotify.com/v1/albums/7pv1g7oSCc9aT7nx1xDUJ3',
#     'id': '7pv1g7oSCc9aT7nx1xDUJ3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f2f25586356c6fddee3da1dd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f2f25586356c6fddee3da1dd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f2f25586356c6fddee3da1dd',
#       'width': 64}],
#     'name': 'Rowdy Boy Vijay Devarakonda',
#     'release_date': '2019-05-04',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:7pv1g7oSCc9aT7nx1xDUJ3',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Q80PCEUBCiRhLSWdQApNt'},
#       'href': 'https://api.spotify.com/v1/artists/3Q80PCEUBCiRhLSWdQApNt',
#       'id': '3Q80PCEUBCiRhLSWdQApNt',
#       'name': 'Jakes Bejoy',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Q80PCEUBCiRhLSWdQApNt'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7pv1g7oSCc9aT7nx1xDUJ3'},
#     'total_tracks': 15},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qjJw7ZM2ekDSahLXPjIlN'},
#      'href': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN',
#      'id': '7qjJw7ZM2ekDSahLXPjIlN',
#      'name': 'Sid Sriram',
#      'type': 'artist',
#      'uri': 'spotify:artist:7qjJw7ZM2ekDSahLXPjIlN'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 266715,
#    'external_ids': {'isrc': 'INA091816158'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5CWQ9WBbd1HESogIIuTlVI'},
#    'href': 'https://api.spotify.com/v1/tracks/5CWQ9WBbd1HESogIIuTlVI',
#    'id': '5CWQ9WBbd1HESogIIuTlVI',
#    'name': 'Inkem Inkem Inkem Kaavaale',
#    'popularity': 33,
#    'uri': 'spotify:track:5CWQ9WBbd1HESogIIuTlVI',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-11-01T13:28:45Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/0nJiWxWeUSYUq3xpzNKs5d',
#     'id': '0nJiWxWeUSYUq3xpzNKs5d',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27371cc7c112a85908f0192aa70',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0271cc7c112a85908f0192aa70',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485171cc7c112a85908f0192aa70',
#       'width': 64}],
#     'name': 'Son Of Satyamurthy',
#     'release_date': '2015-03-15',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0nJiWxWeUSYUq3xpzNKs5d',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#       'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#       'id': '5sSzCxHtgL82pYDvx2QyEU',
#       'name': 'Devi Sri Prasad',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0nJiWxWeUSYUq3xpzNKs5d'},
#     'total_tracks': 8},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2pVurQy6iuWWx707gilSdX'},
#      'href': 'https://api.spotify.com/v1/artists/2pVurQy6iuWWx707gilSdX',
#      'id': '2pVurQy6iuWWx707gilSdX',
#      'name': 'Yazin Nizar',
#      'type': 'artist',
#      'uri': 'spotify:artist:2pVurQy6iuWWx707gilSdX'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 262488,
#    'external_ids': {'isrc': 'INA091514797'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2C72bOiY3kbCgDBBznoejk'},
#    'href': 'https://api.spotify.com/v1/tracks/2C72bOiY3kbCgDBBznoejk',
#    'id': '2C72bOiY3kbCgDBBznoejk',
#    'name': 'Seethakaalam',
#    'popularity': 61,
#    'uri': 'spotify:track:2C72bOiY3kbCgDBBznoejk',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-11-01T13:33:16Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/33thvrIEnv8XgCjuljJkwM',
#     'id': '33thvrIEnv8XgCjuljJkwM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273723c541e574b10a500d22e4d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02723c541e574b10a500d22e4d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851723c541e574b10a500d22e4d',
#       'width': 64}],
#     'name': 'Mr Perfect',
#     'release_date': '2011-03-18',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:33thvrIEnv8XgCjuljJkwM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#       'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#       'id': '5sSzCxHtgL82pYDvx2QyEU',
#       'name': 'Devi Sri Prasad',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/33thvrIEnv8XgCjuljJkwM'},
#     'total_tracks': 9},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0oOet2f43PA68X5RxKobEy'},
#      'href': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy',
#      'id': '0oOet2f43PA68X5RxKobEy',
#      'name': 'Shreya Ghoshal',
#      'type': 'artist',
#      'uri': 'spotify:artist:0oOet2f43PA68X5RxKobEy'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 297130,
#    'external_ids': {'isrc': 'INA091112812'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0JLLcOdBUKfDtzY0seXQHC'},
#    'href': 'https://api.spotify.com/v1/tracks/0JLLcOdBUKfDtzY0seXQHC',
#    'id': '0JLLcOdBUKfDtzY0seXQHC',
#    'name': 'Chali Chaliga',
#    'popularity': 51,
#    'uri': 'spotify:track:0JLLcOdBUKfDtzY0seXQHC',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-11-01T13:33:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
# ...
#    'uri': 'spotify:track:5WnlpdU8nHfbogtkAl6k8E',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-04-14T09:38:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/19kRwbWwLuNJduIg7G7mnt',
#     'id': '19kRwbWwLuNJduIg7G7mnt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e18119db1babc8fb801573e7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e18119db1babc8fb801573e7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e18119db1babc8fb801573e7',
#       'width': 64}],
#     'name': 'ABCD - American Born Confused Desi (Original Motion Picture Soundtrack)',
#     'release_date': '2019-06-01',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:19kRwbWwLuNJduIg7G7mnt',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4penrzAbWok4rhnaZuwF9V'},
#       'href': 'https://api.spotify.com/v1/artists/4penrzAbWok4rhnaZuwF9V',
#       'id': '4penrzAbWok4rhnaZuwF9V',
#       'name': 'Judah Sandhy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4penrzAbWok4rhnaZuwF9V'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/19kRwbWwLuNJduIg7G7mnt'},
#     'total_tracks': 5},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1H4ZvA2yyK7wCmbvEUWvPn'},
#      'href': 'https://api.spotify.com/v1/artists/1H4ZvA2yyK7wCmbvEUWvPn',
#      'id': '1H4ZvA2yyK7wCmbvEUWvPn',
#      'name': 'Rahul Sipligunj',
#      'type': 'artist',
#      'uri': 'spotify:artist:1H4ZvA2yyK7wCmbvEUWvPn'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 222333,
#    'external_ids': {'isrc': 'INH411910167'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7iw8UK1hzvAvvXKhSeKFeg'},
#    'href': 'https://api.spotify.com/v1/tracks/7iw8UK1hzvAvvXKhSeKFeg',
#    'id': '7iw8UK1hzvAvvXKhSeKFeg',
#    'name': 'Celebrity',
#    'popularity': 9,
#    'uri': 'spotify:track:7iw8UK1hzvAvvXKhSeKFeg',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-04-14T09:38:56Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/19kRwbWwLuNJduIg7G7mnt',
#     'id': '19kRwbWwLuNJduIg7G7mnt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e18119db1babc8fb801573e7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e18119db1babc8fb801573e7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e18119db1babc8fb801573e7',
#       'width': 64}],
#     'name': 'ABCD - American Born Confused Desi (Original Motion Picture Soundtrack)',
#     'release_date': '2019-06-01',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:19kRwbWwLuNJduIg7G7mnt',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4penrzAbWok4rhnaZuwF9V'},
#       'href': 'https://api.spotify.com/v1/artists/4penrzAbWok4rhnaZuwF9V',
#       'id': '4penrzAbWok4rhnaZuwF9V',
#       'name': 'Judah Sandhy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4penrzAbWok4rhnaZuwF9V'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/19kRwbWwLuNJduIg7G7mnt'},
#     'total_tracks': 5},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qjJw7ZM2ekDSahLXPjIlN'},
#      'href': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN',
#      'id': '7qjJw7ZM2ekDSahLXPjIlN',
#      'name': 'Sid Sriram',
#      'type': 'artist',
#      'uri': 'spotify:artist:7qjJw7ZM2ekDSahLXPjIlN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/35LFDqRu6EmXgUqEWeh2j6'},
#      'href': 'https://api.spotify.com/v1/artists/35LFDqRu6EmXgUqEWeh2j6',
#      'id': '35LFDqRu6EmXgUqEWeh2j6',
#      'name': 'Aditi Bhavaraju',
#      'type': 'artist',
#      'uri': 'spotify:artist:35LFDqRu6EmXgUqEWeh2j6'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 243000,
#    'external_ids': {'isrc': 'INH411905703'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4vX7VKZYx1wGAq5DKBTfAF'},
#    'href': 'https://api.spotify.com/v1/tracks/4vX7VKZYx1wGAq5DKBTfAF',
#    'id': '4vX7VKZYx1wGAq5DKBTfAF',
#    'name': 'Mella Mellagaa',
#    'popularity': 50,
#    'uri': 'spotify:track:4vX7VKZYx1wGAq5DKBTfAF',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-04-14T09:40:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yp2xosrwgj2v7ycvwz2e2oszy'},
#    'href': 'https://api.spotify.com/v1/users/yp2xosrwgj2v7ycvwz2e2oszy',
#    'id': 'yp2xosrwgj2v7ycvwz2e2oszy',
#    'type': 'user',
#    'uri': 'spotify:user:yp2xosrwgj2v7ycvwz2e2oszy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/2ANEQWadCAxBHp3Wr9b6aZ',
#     'id': '2ANEQWadCAxBHp3Wr9b6aZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273398774126886b941dde117d9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02398774126886b941dde117d9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851398774126886b941dde117d9',
#       'width': 64}],
#     'name': 'Okka Kshanam',
#     'release_date': '2017-12-22',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:2ANEQWadCAxBHp3Wr9b6aZ',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AMxH9QIPZbK8ND8C9j4Ss'},
#       'href': 'https://api.spotify.com/v1/artists/3AMxH9QIPZbK8ND8C9j4Ss',
#       'id': '3AMxH9QIPZbK8ND8C9j4Ss',
#       'name': 'Mani Sharma',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AMxH9QIPZbK8ND8C9j4Ss'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2ANEQWadCAxBHp3Wr9b6aZ'},
#     'total_tracks': 3},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LWyVEIBnx7MoRBhQxu9om'},
#      'href': 'https://api.spotify.com/v1/artists/6LWyVEIBnx7MoRBhQxu9om',
#      'id': '6LWyVEIBnx7MoRBhQxu9om',
#      'name': 'Anurag Kulkarni',
#      'type': 'artist',
#      'uri': 'spotify:artist:6LWyVEIBnx7MoRBhQxu9om'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4B6xPj5DgfYc9mrRzetkgo'},
#      'href': 'https://api.spotify.com/v1/artists/4B6xPj5DgfYc9mrRzetkgo',
#      'id': '4B6xPj5DgfYc9mrRzetkgo',
#      'name': 'Sahithi',
#      'type': 'artist',
#      'uri': 'spotify:artist:4B6xPj5DgfYc9mrRzetkgo'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 263244,
#    'external_ids': {'isrc': 'INS181702321'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0m2P7M2IBLK08aWfhcHOMF'},
#    'href': 'https://api.spotify.com/v1/tracks/0m2P7M2IBLK08aWfhcHOMF',
#    'id': '0m2P7M2IBLK08aWfhcHOMF',
#    'name': 'So Many So Many',
#    'popularity': 0,
#    'uri': 'spotify:track:0m2P7M2IBLK08aWfhcHOMF',
#    'is_local': False},
#   'video_thumbnail': {'url': None}}]

# %%
len((data['items']))
# Out:
# 61

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'type': 'album',
#  'album_type': 'single',
#  'href': 'https://api.spotify.com/v1/albums/3rpmVMH5kV6jYkzSmlpn5u',
#  'id': '3rpmVMH5kV6jYkzSmlpn5u',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273dc3f0e7ab81ade4bd20ab217',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02dc3f0e7ab81ade4bd20ab217',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851dc3f0e7ab81ade4bd20ab217',
#    'width': 64}],
#  'name': 'Rangam',
#  'release_date': '2011-04-09',
#  'release_date_precision': 'day',
#  'uri': 'spotify:album:3rpmVMH5kV6jYkzSmlpn5u',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#    'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#    'id': '29aw5YCdIw2FEXYyAJZI8l',
#    'name': 'Harris Jayaraj',
#    'type': 'artist',
#    'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/3rpmVMH5kV6jYkzSmlpn5u'},
#  'total_tracks': 6}

# %%
data['items'][0]['track']['album']['id']
# Out:
# '3rpmVMH5kV6jYkzSmlpn5u'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Rangam'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2011-04-09'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 6

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/3rpmVMH5kV6jYkzSmlpn5u'}

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/3rpmVMH5kV6jYkzSmlpn5u'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id': album_id,'album_name': album_name, 'release_date':album_release_date, 'total_tracks':album_total_tracks, 'url':album_url  }
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '3rpmVMH5kV6jYkzSmlpn5u',
#   'album_name': 'Rangam',
#   'release_date': '2011-04-09',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/3rpmVMH5kV6jYkzSmlpn5u'},
#  {'album_id': '6LDkuQZTLwRVja4CpYOCuu',
#   'album_name': 'Beauty & The Beats of Samantha',
#   'release_date': '2019-04-26',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6LDkuQZTLwRVja4CpYOCuu'},
#  {'album_id': '0U9GjYJr2K1CK8tOax7Hrf',
#   'album_name': 'Mirchi',
#   'release_date': '2013-01-05',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/0U9GjYJr2K1CK8tOax7Hrf'},
#  {'album_id': '7vuWNVdv7zSwgHJ7qx26O4',
#   'album_name': 'Aarya - 2 (Original Motion Picture Soundtrack)',
#   'release_date': '2009-10-30',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/7vuWNVdv7zSwgHJ7qx26O4'},
#  {'album_id': '7pv1g7oSCc9aT7nx1xDUJ3',
#   'album_name': 'Rowdy Boy Vijay Devarakonda',
#   'release_date': '2019-05-04',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7pv1g7oSCc9aT7nx1xDUJ3'},
#  {'album_id': '0nJiWxWeUSYUq3xpzNKs5d',
#   'album_name': 'Son Of Satyamurthy',
#   'release_date': '2015-03-15',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/0nJiWxWeUSYUq3xpzNKs5d'},
#  {'album_id': '33thvrIEnv8XgCjuljJkwM',
#   'album_name': 'Mr Perfect',
#   'release_date': '2011-03-18',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/33thvrIEnv8XgCjuljJkwM'},
#  {'album_id': '2OPvJhDyy9YvHJT3xt7Zwh',
#   'album_name': 'Fidaa',
#   'release_date': '2017-06-30',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/2OPvJhDyy9YvHJT3xt7Zwh'},
#  {'album_id': '1pE2RYH3lcDdLpMVjBslBp',
#   'album_name': 'Nenu Sailaja',
#   'release_date': '2015-12-21',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/1pE2RYH3lcDdLpMVjBslBp'},
#  {'album_id': '4rjF7pEttnd3hMEt7iuzgk',
#   'album_name': 'Attarrintiki Daaredi',
#   'release_date': '2013-07-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/4rjF7pEttnd3hMEt7iuzgk'},
#  {'album_id': '4TmtWuheIr8ejxIjBpLU2u',
#   'album_name': 'Jalsa',
#   'release_date': '2008-02-28',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4TmtWuheIr8ejxIjBpLU2u'},
#  {'album_id': '1md4f58fUAJK3UoY1qWAVR',
#   'album_name': 'Adiga Adiga (From "Ninnu Kori")',
#   'release_date': '2017-05-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1md4f58fUAJK3UoY1qWAVR'},
#  {'album_id': '0OI4KhEq8LdWa33Nj1i2qj',
#   'album_name': 'Pillaa Raa (From "RX 100")',
#   'release_date': '2018-06-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0OI4KhEq8LdWa33Nj1i2qj'},
#  {'album_id': '2mutIulE85wKAHrrP0oCuM',
#   'album_name': 'Dhruva',
#   'release_date': '2016-11-09',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/2mutIulE85wKAHrrP0oCuM'},
#  {'album_id': '2wRphkgnlcGKkJIjZpxNvb',
#   'album_name': 'Tholi Prema',
#   'release_date': '2020-01-20',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/2wRphkgnlcGKkJIjZpxNvb'},
#  {'album_id': '2OgVFYem1WFhNgOPuBa9zX',
#   'album_name': 'Ishq',
#   'release_date': '2012-02-03',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/2OgVFYem1WFhNgOPuBa9zX'},
#  {'album_id': '1kGnuSqFejTLaDJefAU7yw',
#   'album_name': 'DJ',
#   'release_date': '2017-05-22',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/1kGnuSqFejTLaDJefAU7yw'},
#  {'album_id': '7pv1g7oSCc9aT7nx1xDUJ3',
#   'album_name': 'Rowdy Boy Vijay Devarakonda',
#   'release_date': '2019-05-04',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7pv1g7oSCc9aT7nx1xDUJ3'},
#  {'album_id': '5B8AmuHx5y2pKQWTTDOo6A',
#   'album_name': 'Holi Special Songs',
#   'release_date': '2019-03-19',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/5B8AmuHx5y2pKQWTTDOo6A'},
#  {'album_id': '1AdvHtbDQU2lOcSCZzB6xz',
#   'album_name': 'Businessman',
#   'release_date': '2011-12-22',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/1AdvHtbDQU2lOcSCZzB6xz'},
#  {'album_id': '35CCKYAkZ8GHzIb1rbDND5',
#   'album_name': 'Hushaaru',
#   'release_date': '2018-10-01',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/35CCKYAkZ8GHzIb1rbDND5'},
#  {'album_id': '6RsL60SSZTVwigjfyY8mD2',
#   'album_name': 'Agnyaathavaasi',
#   'release_date': '2017-11-07',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6RsL60SSZTVwigjfyY8mD2'},
#  {'album_id': '7pv1g7oSCc9aT7nx1xDUJ3',
#   'album_name': 'Rowdy Boy Vijay Devarakonda',
#   'release_date': '2019-05-04',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7pv1g7oSCc9aT7nx1xDUJ3'},
#  {'album_id': '4l1UZrzOz1la6gcFsEuktY',
#   'album_name': 'Mega Power Star',
#   'release_date': '2019-03-25',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/4l1UZrzOz1la6gcFsEuktY'},
#  {'album_id': '6LDkuQZTLwRVja4CpYOCuu',
#   'album_name': 'Beauty & The Beats of Samantha',
#   'release_date': '2019-04-26',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6LDkuQZTLwRVja4CpYOCuu'},
#  {'album_id': '6KVZ6Feu2G6bY1eXwbE6ui',
#   'album_name': 'Unnatundi Gundey (From "Ninnu Kori")',
#   'release_date': '2017-06-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6KVZ6Feu2G6bY1eXwbE6ui'},
#  {'album_id': '4OM6femr6U4dYJwxByQMKX',
#   'album_name': 'Chalo',
#   'release_date': '2017-12-02',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/4OM6femr6U4dYJwxByQMKX'},
#  {'album_id': '2OgVFYem1WFhNgOPuBa9zX',
#   'album_name': 'Ishq',
#   'release_date': '2012-02-03',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/2OgVFYem1WFhNgOPuBa9zX'},
#  {'album_id': '7D1e4SHtUU145PYbUiZ4F7',
#   'album_name': 'Nenu Local',
#   'release_date': '2017-01-12',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/7D1e4SHtUU145PYbUiZ4F7'},
#  {'album_id': '6n7uqqX5fHZEoBXF74KJQS',
#   'album_name': 'Srimanthudu',
#   'release_date': '2015-07-18',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6n7uqqX5fHZEoBXF74KJQS'},
#  {'album_id': '4CO4EDT6CLK1TC6n4yJNUX',
#   'album_name': 'Pokiri',
#   'release_date': '2006-04-08',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/4CO4EDT6CLK1TC6n4yJNUX'},
#  {'album_id': '57x6HaiiJdeTg9yhfoMcSr',
#   'album_name': 'Gabbar Singh',
#   'release_date': '2012-04-15',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/57x6HaiiJdeTg9yhfoMcSr'},
#  {'album_id': '7eJXTAO0qIPduGIE4Pqk5C',
#   'album_name': 'Parugu',
#   'release_date': '2008-04-05',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/7eJXTAO0qIPduGIE4Pqk5C'},
#  {'album_id': '13J2XQOZo0I8ZAufTXFvyd',
#   'album_name': 'Darling (Original Motion Picture Soundtrack)',
#   'release_date': '2010-04-13',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/13J2XQOZo0I8ZAufTXFvyd'},
#  {'album_id': '6n7uqqX5fHZEoBXF74KJQS',
#   'album_name': 'Srimanthudu',
#   'release_date': '2015-07-18',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6n7uqqX5fHZEoBXF74KJQS'},
#  {'album_id': '5pDP183RRSwga8C5XNtRCL',
#   'album_name': 'Gentleman',
#   'release_date': '2016-05-20',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/5pDP183RRSwga8C5XNtRCL'},
#  {'album_id': '5qpZDTqwLtGVwWlSz8TcHV',
#   'album_name': 'LIE',
#   'release_date': '2017-06-12',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/5qpZDTqwLtGVwWlSz8TcHV'},
#  {'album_id': '2mutIulE85wKAHrrP0oCuM',
#   'album_name': 'Dhruva',
#   'release_date': '2016-11-09',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/2mutIulE85wKAHrrP0oCuM'},
#  {'album_id': '0j9Vp2crMI3DB942oviGvc',
#   'album_name': 'Kumari 21 F',
#   'release_date': '2015-10-31',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/0j9Vp2crMI3DB942oviGvc'},
#  {'album_id': '2wRphkgnlcGKkJIjZpxNvb',
#   'album_name': 'Tholi Prema',
#   'release_date': '2020-01-20',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/2wRphkgnlcGKkJIjZpxNvb'},
#  {'album_id': '4rjF7pEttnd3hMEt7iuzgk',
#   'album_name': 'Attarrintiki Daaredi',
#   'release_date': '2013-07-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/4rjF7pEttnd3hMEt7iuzgk'},
#  {'album_id': '57x6HaiiJdeTg9yhfoMcSr',
#   'album_name': 'Gabbar Singh',
#   'release_date': '2012-04-15',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/57x6HaiiJdeTg9yhfoMcSr'},
#  {'album_id': '0jgL9SVtLAWxM3VNKaQyaC',
#   'album_name': 'Rabhasa',
#   'release_date': '2014-08-01',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/0jgL9SVtLAWxM3VNKaQyaC'},
#  {'album_id': '5GfSI5flSZJaNh0Gwq3l61',
#   'album_name': 'Mukunda',
#   'release_date': '2014-12-03',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/5GfSI5flSZJaNh0Gwq3l61'},
#  {'album_id': '7n61GzJSBuZGrm8U1V9TLd',
#   'album_name': 'Yemaaya Chesave (Original Motion Picture Soundtrack)',
#   'release_date': '2010-01-29',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/7n61GzJSBuZGrm8U1V9TLd'},
#  {'album_id': '6nlrhHVOHgVohenouAbuje',
#   'album_name': 'Athadu',
#   'release_date': '2005',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6nlrhHVOHgVohenouAbuje'},
#  {'album_id': '37evPVtdfVL0X4Sji9tQdu',
#   'album_name': 'Kushi',
#   'release_date': '2001-03-27',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/37evPVtdfVL0X4Sji9tQdu'},
#  {'album_id': '6o9ysd0MFQXd6g4eWtcvNq',
#   'album_name': 'Idharammayilatho',
#   'release_date': '2013-04-28',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6o9ysd0MFQXd6g4eWtcvNq'},
#  {'album_id': '2aNP8WRBq1cUgP4hvblCVa',
#   'album_name': 'Manmadhudu',
#   'release_date': '2002',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/2aNP8WRBq1cUgP4hvblCVa'},
#  {'album_id': '5qmlAvprLWH32VE6oi2Wpe',
#   'album_name': 'Premam',
#   'release_date': '2016-08-18',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/5qmlAvprLWH32VE6oi2Wpe'},
#  {'album_id': '7pv1g7oSCc9aT7nx1xDUJ3',
#   'album_name': 'Rowdy Boy Vijay Devarakonda',
#   'release_date': '2019-05-04',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7pv1g7oSCc9aT7nx1xDUJ3'},
#  {'album_id': '4TmtWuheIr8ejxIjBpLU2u',
#   'album_name': 'Jalsa',
#   'release_date': '2008-02-28',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4TmtWuheIr8ejxIjBpLU2u'},
#  {'album_id': '0ezsoNG85fJtdsyobZNu68',
#   'album_name': 'Valmiki (Original Motion Picture Soundtrack)',
#   'release_date': '2019-09-12',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/0ezsoNG85fJtdsyobZNu68'},
#  {'album_id': '2FL2qOOkZz0JFtS2Fzazf4',
#   'album_name': 'Sarileru Neekevvaru - A Tribute To The Indian Army',
#   'release_date': '2019-08-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2FL2qOOkZz0JFtS2Fzazf4'},
#  {'album_id': '7APxU4HUrwGON54JHXoDx4',
#   'album_name': 'Ruler',
#   'release_date': '2019-12-01',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/7APxU4HUrwGON54JHXoDx4'},
#  {'album_id': '0y35Kd8IAWamg1qsAg6mpA',
#   'album_name': 'Aswathama',
#   'release_date': '2019-12-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0y35Kd8IAWamg1qsAg6mpA'},
#  {'album_id': '0SVBhjxNR6eCoN1eN93A9h',
#   'album_name': 'Oo… Baava… (From "Prati Roju Pandaage")',
#   'release_date': '2019-11-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0SVBhjxNR6eCoN1eN93A9h'},
#  {'album_id': '1mZYQfcWj83VOe1v7wpYMr',
#   'album_name': 'Saaho',
#   'release_date': '2019-08-28',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1mZYQfcWj83VOe1v7wpYMr'},
#  {'album_id': '19kRwbWwLuNJduIg7G7mnt',
#   'album_name': 'ABCD - American Born Confused Desi (Original Motion Picture Soundtrack)',
#   'release_date': '2019-06-01',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/19kRwbWwLuNJduIg7G7mnt'},
#  {'album_id': '19kRwbWwLuNJduIg7G7mnt',
#   'album_name': 'ABCD - American Born Confused Desi (Original Motion Picture Soundtrack)',
#   'release_date': '2019-06-01',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/19kRwbWwLuNJduIg7G7mnt'},
#  {'album_id': '2ANEQWadCAxBHp3Wr9b6aZ',
#   'album_name': 'Okka Kshanam',
#   'release_date': '2017-12-22',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/2ANEQWadCAxBHp3Wr9b6aZ'}]

# %%
data['items'][1]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2WF7juQ5oilpZCqikRtP'},
#   'href': 'https://api.spotify.com/v1/artists/5a2WF7juQ5oilpZCqikRtP',
#   'id': '5a2WF7juQ5oilpZCqikRtP',
#   'name': 'Rahul Nambiar',
#   'type': 'artist',
#   'uri': 'spotify:artist:5a2WF7juQ5oilpZCqikRtP'}]

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '6qcMtXmofIpnR9TBhgamMR',
#   'artist_name': 'Aalaap Raju',
#   'external_url': 'https://api.spotify.com/v1/artists/6qcMtXmofIpnR9TBhgamMR'},
#  {'artist_id': '1EAoBVsvTYarQhO6i9zAG9',
#   'artist_name': 'Prasanthini',
#   'external_url': 'https://api.spotify.com/v1/artists/1EAoBVsvTYarQhO6i9zAG9'},
#  {'artist_id': '5a2WF7juQ5oilpZCqikRtP',
#   'artist_name': 'Rahul Nambiar',
#   'external_url': 'https://api.spotify.com/v1/artists/5a2WF7juQ5oilpZCqikRtP'},
#  {'artist_id': '4iA6bUhiZyvRKJf4FNVX39',
#   'artist_name': 'Vijay Prakash',
#   'external_url': 'https://api.spotify.com/v1/artists/4iA6bUhiZyvRKJf4FNVX39'},
#  {'artist_id': '0vWyMSeg4ixQ98Srb8E4y5',
#   'artist_name': 'Anitha Karthikeyan',
#   'external_url': 'https://api.spotify.com/v1/artists/0vWyMSeg4ixQ98Srb8E4y5'},
#  {'artist_id': '5sSzCxHtgL82pYDvx2QyEU',
#   'artist_name': 'Devi Sri Prasad',
#   'external_url': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU'},
#  {'artist_id': '4fEkbug6kZzzJ8eYX6Kbbp',
#   'artist_name': 'KK',
#   'external_url': 'https://api.spotify.com/v1/artists/4fEkbug6kZzzJ8eYX6Kbbp'},
#  {'artist_id': '7qjJw7ZM2ekDSahLXPjIlN',
#   'artist_name': 'Sid Sriram',
#   'external_url': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN'},
#  {'artist_id': '2pVurQy6iuWWx707gilSdX',
#   'artist_name': 'Yazin Nizar',
#   'external_url': 'https://api.spotify.com/v1/artists/2pVurQy6iuWWx707gilSdX'},
#  {'artist_id': '0oOet2f43PA68X5RxKobEy',
#   'artist_name': 'Shreya Ghoshal',
#   'external_url': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy'},
#  {'artist_id': '1TpuHZaoRQMiKcMRN5DjDY',
#   'artist_name': 'Madhu Priya',
#   'external_url': 'https://api.spotify.com/v1/artists/1TpuHZaoRQMiKcMRN5DjDY'},
#  {'artist_id': '0T6ky5WnBqEazCMELEcQbn',
#   'artist_name': 'Ramky',
#   'external_url': 'https://api.spotify.com/v1/artists/0T6ky5WnBqEazCMELEcQbn'},
#  {'artist_id': '4xUI2yJe8cZHYGhS8rk1oR',
#   'artist_name': 'Prudhvi Chandra',
#   'external_url': 'https://api.spotify.com/v1/artists/4xUI2yJe8cZHYGhS8rk1oR'},
#  {'artist_id': '5sSzCxHtgL82pYDvx2QyEU',
#   'artist_name': 'Devi Sri Prasad',
#   'external_url': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU'},
#  {'artist_id': '4fEkbug6kZzzJ8eYX6Kbbp',
#   'artist_name': 'KK',
#   'external_url': 'https://api.spotify.com/v1/artists/4fEkbug6kZzzJ8eYX6Kbbp'},
#  {'artist_id': '4xlqU0G9EloUPHL1qlmWY6',
#   'artist_name': 'Gopi Sundar',
#   'external_url': 'https://api.spotify.com/v1/artists/4xlqU0G9EloUPHL1qlmWY6'},
#  {'artist_id': '7qjJw7ZM2ekDSahLXPjIlN',
#   'artist_name': 'Sid Sriram',
#   'external_url': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN'},
#  {'artist_id': '7uc8AizyyDG8ujFdTxZ7q5',
#   'artist_name': 'Chaitan Bharadwaj',
#   'external_url': 'https://api.spotify.com/v1/artists/7uc8AizyyDG8ujFdTxZ7q5'},
#  {'artist_id': '6LWyVEIBnx7MoRBhQxu9om',
#   'artist_name': 'Anurag Kulkarni',
#   'external_url': 'https://api.spotify.com/v1/artists/6LWyVEIBnx7MoRBhQxu9om'},
#  {'artist_id': '7xgN0GCVgPxHiU8p8PIYfk',
#   'artist_name': 'Padmalatha',
#   'external_url': 'https://api.spotify.com/v1/artists/7xgN0GCVgPxHiU8p8PIYfk'},
#  {'artist_id': '0ioIcfFt7AbPVmSInTsWX6',
#   'artist_name': 'Sniggy',
#   'external_url': 'https://api.spotify.com/v1/artists/0ioIcfFt7AbPVmSInTsWX6'},
#  {'artist_id': '2FgHPfRprDaylrSRVf1UlN',
#   'artist_name': 'Thaman S',
#   'external_url': 'https://api.spotify.com/v1/artists/2FgHPfRprDaylrSRVf1UlN'},
#  {'artist_id': '4IKVDbCSBTxBeAsMKjAuTs',
#   'artist_name': 'Armaan Malik',
#   'external_url': 'https://api.spotify.com/v1/artists/4IKVDbCSBTxBeAsMKjAuTs'},
#  {'artist_id': '3S9UbmvOKXtONgwJOh2Ngh',
#   'artist_name': 'Shree Mani',
#   'external_url': 'https://api.spotify.com/v1/artists/3S9UbmvOKXtONgwJOh2Ngh'},
#  {'artist_id': '4R21B9eF1iM1yLVNY5SN1d',
#   'artist_name': 'Adnan Sami, Nithya Menon',
#   'external_url': 'https://api.spotify.com/v1/artists/4R21B9eF1iM1yLVNY5SN1d'},
#  {'artist_id': '1urtr0Wr3oFJVeTMF2aqPm',
#   'artist_name': 'M.L.R. Karthikeyan',
#   'external_url': 'https://api.spotify.com/v1/artists/1urtr0Wr3oFJVeTMF2aqPm'},
#  {'artist_id': '2IUtwMti1OiT3lkW6RubgH',
#   'artist_name': 'K. S. Chithra',
#   'external_url': 'https://api.spotify.com/v1/artists/2IUtwMti1OiT3lkW6RubgH'},
#  {'artist_id': '7qjJw7ZM2ekDSahLXPjIlN',
#   'artist_name': 'Sid Sriram',
#   'external_url': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN'},
#  {'artist_id': '7gVwxXFMkSYwYGNHIt77qU',
#   'artist_name': 'Ramya',
#   'external_url': 'https://api.spotify.com/v1/artists/7gVwxXFMkSYwYGNHIt77qU'},
#  {'artist_id': '5a2WF7juQ5oilpZCqikRtP',
#   'artist_name': 'Rahul Nambiar',
#   'external_url': 'https://api.spotify.com/v1/artists/5a2WF7juQ5oilpZCqikRtP'},
#  {'artist_id': '1YgwDFQvwbprfD17tGUjje',
#   'artist_name': 'Shivani',
#   'external_url': 'https://api.spotify.com/v1/artists/1YgwDFQvwbprfD17tGUjje'},
#  {'artist_id': '3R0YzDT1gl2mMDLMrgdNjR',
#   'artist_name': 'Suchitra',
#   'external_url': 'https://api.spotify.com/v1/artists/3R0YzDT1gl2mMDLMrgdNjR'},
#  {'artist_id': '2FgHPfRprDaylrSRVf1UlN',
#   'artist_name': 'Thaman S',
#   'external_url': 'https://api.spotify.com/v1/artists/2FgHPfRprDaylrSRVf1UlN'},
#  {'artist_id': '7qjJw7ZM2ekDSahLXPjIlN',
#   'artist_name': 'Sid Sriram',
#   'external_url': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '5UJ2sHO2ELrgW6aXeRLTQQ',
#   'artist_name': 'Chinmayi',
#   'external_url': 'https://api.spotify.com/v1/artists/5UJ2sHO2ELrgW6aXeRLTQQ'},
#  {'artist_id': '0LSPREIgGMZXCuKVel7LVD',
#   'artist_name': 'Karthik',
#   'external_url': 'https://api.spotify.com/v1/artists/0LSPREIgGMZXCuKVel7LVD'},
#  {'artist_id': '0oOet2f43PA68X5RxKobEy',
#   'artist_name': 'Shreya Ghoshal',
#   'external_url': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '0LSPREIgGMZXCuKVel7LVD',
#   'artist_name': 'Karthik',
#   'external_url': 'https://api.spotify.com/v1/artists/0LSPREIgGMZXCuKVel7LVD'},
#  {'artist_id': '5UJ2sHO2ELrgW6aXeRLTQQ',
#   'artist_name': 'Chinmayi',
#   'external_url': 'https://api.spotify.com/v1/artists/5UJ2sHO2ELrgW6aXeRLTQQ'},
#  {'artist_id': '6LWyVEIBnx7MoRBhQxu9om',
#   'artist_name': 'Anurag Kulkarni',
#   'external_url': 'https://api.spotify.com/v1/artists/6LWyVEIBnx7MoRBhQxu9om'},
#  {'artist_id': '27dNKsHZrQKGnAlFCLDlzd',
#   'artist_name': 'Mahati Swara Sagar',
#   'external_url': 'https://api.spotify.com/v1/artists/27dNKsHZrQKGnAlFCLDlzd'},
#  {'artist_id': '3vLK5eWo5XTYd8jAuPs26l',
#   'artist_name': 'Raja Hasan, Anoop Rubens, Sravani',
#   'external_url': 'https://api.spotify.com/v1/artists/3vLK5eWo5XTYd8jAuPs26l'},
#  {'artist_id': '7FaGCZiP3s6X7jQTB8EhfI',
#   'artist_name': 'Naresh Iyer',
#   'external_url': 'https://api.spotify.com/v1/artists/7FaGCZiP3s6X7jQTB8EhfI'},
#  {'artist_id': '7uTF7CgQzu55VR10qqG2yC',
#   'artist_name': 'Manisha Eerabathini',
#   'external_url': 'https://api.spotify.com/v1/artists/7uTF7CgQzu55VR10qqG2yC'},
#  {'artist_id': '6CWBs7ul78QwnBrcOCwhf5',
#   'artist_name': 'Sagar',
#   'external_url': 'https://api.spotify.com/v1/artists/6CWBs7ul78QwnBrcOCwhf5'},
#  {'artist_id': '3R0YzDT1gl2mMDLMrgdNjR',
#   'artist_name': 'Suchitra',
#   'external_url': 'https://api.spotify.com/v1/artists/3R0YzDT1gl2mMDLMrgdNjR'},
#  {'artist_id': '7DX2CLnA9ajgQuNf5jqEXl',
#   'artist_name': 'Nihal',
#   'external_url': 'https://api.spotify.com/v1/artists/7DX2CLnA9ajgQuNf5jqEXl'},
#  {'artist_id': '1SJOL9HJ08YOn92lFcYf8a',
#   'artist_name': 'Shankar Mahadevan',
#   'external_url': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a'},
#  {'artist_id': '5Rj7UMjxB4u5OZnS5c1rXF',
#   'artist_name': 'Gopika Poornima',
#   'external_url': 'https://api.spotify.com/v1/artists/5Rj7UMjxB4u5OZnS5c1rXF'},
#  {'artist_id': '6Xwwyea7gPu9LG0nWWHg0v',
#   'artist_name': 'Saketh Naidu',
#   'external_url': 'https://api.spotify.com/v1/artists/6Xwwyea7gPu9LG0nWWHg0v'},
#  {'artist_id': '5VVN3xZw1i2qihfITZlvCZ',
#   'artist_name': 'G. V. Prakash',
#   'external_url': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ'},
#  {'artist_id': '2pVurQy6iuWWx707gilSdX',
#   'artist_name': 'Yazin Nizar',
#   'external_url': 'https://api.spotify.com/v1/artists/2pVurQy6iuWWx707gilSdX'},
#  {'artist_id': '5sSzCxHtgL82pYDvx2QyEU',
#   'artist_name': 'Devi Sri Prasad',
#   'external_url': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU'},
#  {'artist_id': '06V3WlbxMpgl639AJoFH7C',
#   'artist_name': 'Sri Krishna',
#   'external_url': 'https://api.spotify.com/v1/artists/06V3WlbxMpgl639AJoFH7C'},
#  {'artist_id': '2JEjaa7hWhE1BbL3OcoeFR',
#   'artist_name': 'Sujatha',
#   'external_url': 'https://api.spotify.com/v1/artists/2JEjaa7hWhE1BbL3OcoeFR'},
#  {'artist_id': '1H4ZvA2yyK7wCmbvEUWvPn',
#   'artist_name': 'Rahul Sipligunj',
#   'external_url': 'https://api.spotify.com/v1/artists/1H4ZvA2yyK7wCmbvEUWvPn'},
#  {'artist_id': '4svvMm4TQnkphZJfhLCzzv',
#   'artist_name': 'Ramya Behara',
#   'external_url': 'https://api.spotify.com/v1/artists/4svvMm4TQnkphZJfhLCzzv'},
#  {'artist_id': '7zFBW2JxM4bgTTKxCRcS8Q',
#   'artist_name': 'Hiphop Tamizha',
#   'external_url': 'https://api.spotify.com/v1/artists/7zFBW2JxM4bgTTKxCRcS8Q'},
#  {'artist_id': '3tPQOjkxO3mrYrrgkTeXgH',
#   'artist_name': 'Nikhita Gandhi',
#   'external_url': 'https://api.spotify.com/v1/artists/3tPQOjkxO3mrYrrgkTeXgH'},
#  {'artist_id': '2pVurQy6iuWWx707gilSdX',
#   'artist_name': 'Yazin Nizar',
#   'external_url': 'https://api.spotify.com/v1/artists/2pVurQy6iuWWx707gilSdX'},
#  {'artist_id': '2FgHPfRprDaylrSRVf1UlN',
#   'artist_name': 'Thaman S',
#   'external_url': 'https://api.spotify.com/v1/artists/2FgHPfRprDaylrSRVf1UlN'},
#  {'artist_id': '4tejKImNVmDcORNBuZ1l14',
#   'artist_name': 'Kala Bhairava',
#   'external_url': 'https://api.spotify.com/v1/artists/4tejKImNVmDcORNBuZ1l14'},
#  {'artist_id': '3S9UbmvOKXtONgwJOh2Ngh',
#   'artist_name': 'Shree Mani',
#   'external_url': 'https://api.spotify.com/v1/artists/3S9UbmvOKXtONgwJOh2Ngh'},
#  {'artist_id': '4iA6bUhiZyvRKJf4FNVX39',
#   'artist_name': 'Vijay Prakash',
#   'external_url': 'https://api.spotify.com/v1/artists/4iA6bUhiZyvRKJf4FNVX39'},
#  {'artist_id': '1urtr0Wr3oFJVeTMF2aqPm',
#   'artist_name': 'M.L.R. Karthikeyan',
#   'external_url': 'https://api.spotify.com/v1/artists/1urtr0Wr3oFJVeTMF2aqPm'},
#  {'artist_id': '6ewi1Fnj0zJrkWtQJl2668',
#   'artist_name': 'Vaddepalli Srinivas',
#   'external_url': 'https://api.spotify.com/v1/artists/6ewi1Fnj0zJrkWtQJl2668'},
#  {'artist_id': '43PyuGRQ8dxRmOuFHHdybi',
#   'artist_name': 'Pawan Kalyan',
#   'external_url': 'https://api.spotify.com/v1/artists/43PyuGRQ8dxRmOuFHHdybi'},
#  {'artist_id': '4gYivvQ8ARDxds1heBados',
#   'artist_name': 'Jr. NTR',
#   'external_url': 'https://api.spotify.com/v1/artists/4gYivvQ8ARDxds1heBados'},
#  {'artist_id': '2IUtwMti1OiT3lkW6RubgH',
#   'artist_name': 'K. S. Chithra',
#   'external_url': 'https://api.spotify.com/v1/artists/2IUtwMti1OiT3lkW6RubgH'},
#  {'artist_id': '1mYsTxnqsietFxj1OgoGbG',
#   'artist_name': 'A.R. Rahman',
#   'external_url': 'https://api.spotify.com/v1/artists/1mYsTxnqsietFxj1OgoGbG'},
#  {'artist_id': '61if35zz1W11GejEkxTLEQ',
#   'artist_name': 'Benny Dayal',
#   'external_url': 'https://api.spotify.com/v1/artists/61if35zz1W11GejEkxTLEQ'},
#  {'artist_id': '56cdU5EX1q2eqlhV0w2A6D',
#   'artist_name': 'Kalyani Menon',
#   'external_url': 'https://api.spotify.com/v1/artists/56cdU5EX1q2eqlhV0w2A6D'},
#  {'artist_id': '4fEkbug6kZzzJ8eYX6Kbbp',
#   'artist_name': 'KK',
#   'external_url': 'https://api.spotify.com/v1/artists/4fEkbug6kZzzJ8eYX6Kbbp'},
#  {'artist_id': '74S8YRi4XQ5yf9ToSzuY80',
#   'artist_name': 'Sunitha',
#   'external_url': 'https://api.spotify.com/v1/artists/74S8YRi4XQ5yf9ToSzuY80'},
#  {'artist_id': '3K9qRRRqtuxgBRLxRCxpDl',
#   'artist_name': 'Srinivas',
#   'external_url': 'https://api.spotify.com/v1/artists/3K9qRRRqtuxgBRLxRCxpDl'},
#  {'artist_id': '41BeeC5hYqvtGkM79RYvN4',
#   'artist_name': 'Harini',
#   'external_url': 'https://api.spotify.com/v1/artists/41BeeC5hYqvtGkM79RYvN4'},
#  {'artist_id': '1C7kjT2jleM2qNGK97amtW',
#   'artist_name': 'David Simon',
#   'external_url': 'https://api.spotify.com/v1/artists/1C7kjT2jleM2qNGK97amtW'},
#  {'artist_id': '0vWyMSeg4ixQ98Srb8E4y5',
#   'artist_name': 'Anitha Karthikeyan',
#   'external_url': 'https://api.spotify.com/v1/artists/0vWyMSeg4ixQ98Srb8E4y5'},
#  {'artist_id': '7pN9DLRuxE0QBCzg5GZpFv',
#   'artist_name': 'Venu Srirangam',
#   'external_url': 'https://api.spotify.com/v1/artists/7pN9DLRuxE0QBCzg5GZpFv'},
#  {'artist_id': '0WpkyIAATl5W540KCSEUwX',
#   'artist_name': 'Sumangaly',
#   'external_url': 'https://api.spotify.com/v1/artists/0WpkyIAATl5W540KCSEUwX'},
#  {'artist_id': '0aUQnP4HhUQXcurZl9GJIA',
#   'artist_name': 'Vijay Yesudas',
#   'external_url': 'https://api.spotify.com/v1/artists/0aUQnP4HhUQXcurZl9GJIA'},
#  {'artist_id': '7qjJw7ZM2ekDSahLXPjIlN',
#   'artist_name': 'Sid Sriram',
#   'external_url': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN'},
#  {'artist_id': '0PykiHCcDsMPRV7s67qZ1B',
#   'artist_name': 'Tippu',
#   'external_url': 'https://api.spotify.com/v1/artists/0PykiHCcDsMPRV7s67qZ1B'},
#  {'artist_id': '5Rj7UMjxB4u5OZnS5c1rXF',
#   'artist_name': 'Gopika Poornima',
#   'external_url': 'https://api.spotify.com/v1/artists/5Rj7UMjxB4u5OZnS5c1rXF'},
#  {'artist_id': '0WiZi3Q419nMpAQEqfBCbk',
#   'artist_name': 'Mickey J. Meyer',
#   'external_url': 'https://api.spotify.com/v1/artists/0WiZi3Q419nMpAQEqfBCbk'},
#  {'artist_id': '6LWyVEIBnx7MoRBhQxu9om',
#   'artist_name': 'Anurag Kulkarni',
#   'external_url': 'https://api.spotify.com/v1/artists/6LWyVEIBnx7MoRBhQxu9om'},
#  {'artist_id': '4N917Mxvq7arLEkeWewsH4',
#   'artist_name': 'Sweta Subramanian',
#   'external_url': 'https://api.spotify.com/v1/artists/4N917Mxvq7arLEkeWewsH4'},
#  {'artist_id': '5iFKS1bnBNFWBAmd7mi0vf',
#   'artist_name': 'Deepak Blue',
#   'external_url': 'https://api.spotify.com/v1/artists/5iFKS1bnBNFWBAmd7mi0vf'},
#  {'artist_id': '1VUKYmwzXvpP4lpbNXY9qG',
#   'artist_name': 'Anurag kulkarni, Anusha Mani',
#   'external_url': 'https://api.spotify.com/v1/artists/1VUKYmwzXvpP4lpbNXY9qG'},
#  {'artist_id': '4IKVDbCSBTxBeAsMKjAuTs',
#   'artist_name': 'Armaan Malik',
#   'external_url': 'https://api.spotify.com/v1/artists/4IKVDbCSBTxBeAsMKjAuTs'},
#  {'artist_id': '5i3cSIE4DG6LrWAb3pCeQ0',
#   'artist_name': 'Yamini Ghantasala',
#   'external_url': 'https://api.spotify.com/v1/artists/5i3cSIE4DG6LrWAb3pCeQ0'},
#  {'artist_id': '3lnECmHir8dXsqVV0QuruT',
#   'artist_name': 'Sricharan Pakala',
#   'external_url': 'https://api.spotify.com/v1/artists/3lnECmHir8dXsqVV0QuruT'},
#  {'artist_id': '06V3WlbxMpgl639AJoFH7C',
#   'artist_name': 'Sri Krishna',
#   'external_url': 'https://api.spotify.com/v1/artists/06V3WlbxMpgl639AJoFH7C'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '1OPqAyxsQc8mcRmoNBAnVk',
#   'artist_name': 'Dhvani Bhanushali',
#   'external_url': 'https://api.spotify.com/v1/artists/1OPqAyxsQc8mcRmoNBAnVk'},
#  {'artist_id': '4f7KfxeHq9BiylGmyXepGt',
#   'artist_name': 'Tanishk Bagchi',
#   'external_url': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt'},
#  {'artist_id': '1H4ZvA2yyK7wCmbvEUWvPn',
#   'artist_name': 'Rahul Sipligunj',
#   'external_url': 'https://api.spotify.com/v1/artists/1H4ZvA2yyK7wCmbvEUWvPn'},
#  {'artist_id': '7qjJw7ZM2ekDSahLXPjIlN',
#   'artist_name': 'Sid Sriram',
#   'external_url': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN'},
#  {'artist_id': '35LFDqRu6EmXgUqEWeh2j6',
#   'artist_name': 'Aditi Bhavaraju',
#   'external_url': 'https://api.spotify.com/v1/artists/35LFDqRu6EmXgUqEWeh2j6'},
#  {'artist_id': '6LWyVEIBnx7MoRBhQxu9om',
#   'artist_name': 'Anurag Kulkarni',
#   'external_url': 'https://api.spotify.com/v1/artists/6LWyVEIBnx7MoRBhQxu9om'},
#  {'artist_id': '4B6xPj5DgfYc9mrRzetkgo',
#   'artist_name': 'Sahithi',
#   'external_url': 'https://api.spotify.com/v1/artists/4B6xPj5DgfYc9mrRzetkgo'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id , 'song_name':song_name, 'duration_ms':song_duration, 'url': song_url, 'popularity':song_popularity, 'song_added':song_added, 'album_id':album_id, 'artist_id':artist_id}
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                      album_name  \
# 0  3rpmVMH5kV6jYkzSmlpn5u                                          Rangam
# 1  6LDkuQZTLwRVja4CpYOCuu                  Beauty & The Beats of Samantha
# 2  0U9GjYJr2K1CK8tOax7Hrf                                          Mirchi
# 3  7vuWNVdv7zSwgHJ7qx26O4  Aarya - 2 (Original Motion Picture Soundtrack)
# 4  7pv1g7oSCc9aT7nx1xDUJ3                     Rowdy Boy Vijay Devarakonda
#
#   release_date  total_tracks  \
# 0   2011-04-09             6
# 1   2019-04-26            18
# 2   2013-01-05             7
# 3   2009-10-30             8
# 4   2019-05-04            15
#
#                                                  url
# 0  https://open.spotify.com/album/3rpmVMH5kV6jYkz...
# 1  https://open.spotify.com/album/6LDkuQZTLwRVja4...
# 2  https://open.spotify.com/album/0U9GjYJr2K1CK8t...
# 3  https://open.spotify.com/album/7vuWNVdv7zSwgHJ...
# 4  https://open.spotify.com/album/7pv1g7oSCc9aT7n...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id         artist_name  \
# 0  6qcMtXmofIpnR9TBhgamMR         Aalaap Raju
# 1  1EAoBVsvTYarQhO6i9zAG9         Prasanthini
# 2  5a2WF7juQ5oilpZCqikRtP       Rahul Nambiar
# 3  4iA6bUhiZyvRKJf4FNVX39       Vijay Prakash
# 4  0vWyMSeg4ixQ98Srb8E4y5  Anitha Karthikeyan
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6qcMtXmofIp...
# 1  https://api.spotify.com/v1/artists/1EAoBVsvTYa...
# 2  https://api.spotify.com/v1/artists/5a2WF7juQ5o...
# 3  https://api.spotify.com/v1/artists/4iA6bUhiZyv...
# 4  https://api.spotify.com/v1/artists/0vWyMSeg4ix...

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df.head()
# Out:
#                   song_id                   song_name  duration_ms  \
# 0  6Yqw4HtJuFXleJtgzYXWzT                 Endhuko Emo       330505
# 1  3ydF3JegxOkpoVy9gIfpXC                   Guruvaram       262246
# 2  4AuRsGcSsNqslLywUCWhAG            Idhedho Bagundhe       266760
# 3  57zEYntUat0ofbFpoicN26                  Uppenantha       327640
# 4  5CWQ9WBbd1HESogIIuTlVI  Inkem Inkem Inkem Kaavaale       266715
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6Yqw4HtJuFXleJt...          59
# 1  https://open.spotify.com/track/3ydF3JegxOkpoVy...          27
# 2  https://open.spotify.com/track/4AuRsGcSsNqslLy...          59
# 3  https://open.spotify.com/track/57zEYntUat0ofbF...          64
# 4  https://open.spotify.com/track/5CWQ9WBbd1HESog...          33
#
#              song_added                album_id               artist_id
# 0  2019-11-01T13:14:52Z  3rpmVMH5kV6jYkzSmlpn5u  29aw5YCdIw2FEXYyAJZI8l
# 1  2019-11-01T13:17:31Z  6LDkuQZTLwRVja4CpYOCuu  4xlqU0G9EloUPHL1qlmWY6
# 2  2019-11-01T13:17:41Z  0U9GjYJr2K1CK8tOax7Hrf  5sSzCxHtgL82pYDvx2QyEU
# 3  2019-11-01T13:21:57Z  7vuWNVdv7zSwgHJ7qx26O4  5sSzCxHtgL82pYDvx2QyEU
# 4  2019-11-01T13:28:38Z  7pv1g7oSCc9aT7nx1xDUJ3  3Q80PCEUBCiRhLSWdQApNt

# %%
album_df .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      61 non-null     object
#  1   album_name    61 non-null     object
#  2   release_date  61 non-null     object
#  3   total_tracks  61 non-null     int64
#  4   url           61 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.5+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df  = artist_df.drop_duplicates(subset=['artist_id'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      49 non-null     object
#  1   album_name    49 non-null     object
#  2   release_date  49 non-null     object
#  3   total_tracks  49 non-null     int64
#  4   url           49 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.3+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'], errors='coerce')

# %%
album_df['release_date'].replace('1963','1963-01-01',inplace=True)
# Out:
# <ipython-input-77-2859d7a08d83>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   album_df['release_date'].replace('1963','1963-01-01',inplace=True)

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   3rpmVMH5kV6jYkzSmlpn5u                                             Rangam
# 1   6LDkuQZTLwRVja4CpYOCuu                     Beauty & The Beats of Samantha
# 2   0U9GjYJr2K1CK8tOax7Hrf                                             Mirchi
# 3   7vuWNVdv7zSwgHJ7qx26O4     Aarya - 2 (Original Motion Picture Soundtrack)
# 4   7pv1g7oSCc9aT7nx1xDUJ3                        Rowdy Boy Vijay Devarakonda
# 5   0nJiWxWeUSYUq3xpzNKs5d                                 Son Of Satyamurthy
# 6   33thvrIEnv8XgCjuljJkwM                                         Mr Perfect
# 7   2OPvJhDyy9YvHJT3xt7Zwh                                              Fidaa
# 8   1pE2RYH3lcDdLpMVjBslBp                                       Nenu Sailaja
# 9   4rjF7pEttnd3hMEt7iuzgk                               Attarrintiki Daaredi
# 10  4TmtWuheIr8ejxIjBpLU2u                                              Jalsa
# 11  1md4f58fUAJK3UoY1qWAVR                    Adiga Adiga (From "Ninnu Kori")
# 12  0OI4KhEq8LdWa33Nj1i2qj                         Pillaa Raa (From "RX 100")
# 13  2mutIulE85wKAHrrP0oCuM                                             Dhruva
# 14  2wRphkgnlcGKkJIjZpxNvb                                        Tholi Prema
# 15  2OgVFYem1WFhNgOPuBa9zX                                               Ishq
# 16  1kGnuSqFejTLaDJefAU7yw                                                 DJ
# 18  5B8AmuHx5y2pKQWTTDOo6A                                 Holi Special Songs
# 19  1AdvHtbDQU2lOcSCZzB6xz                                        Businessman
# 20  35CCKYAkZ8GHzIb1rbDND5                                           Hushaaru
# 21  6RsL60SSZTVwigjfyY8mD2                                     Agnyaathavaasi
# 23  4l1UZrzOz1la6gcFsEuktY                                    Mega Power Star
# 25  6KVZ6Feu2G6bY1eXwbE6ui               Unnatundi Gundey (From "Ninnu Kori")
# 26  4OM6femr6U4dYJwxByQMKX                                              Chalo
# 28  7D1e4SHtUU145PYbUiZ4F7                                         Nenu Local
# 29  6n7uqqX5fHZEoBXF74KJQS                                        Srimanthudu
# 30  4CO4EDT6CLK1TC6n4yJNUX                                             Pokiri
# 31  57x6HaiiJdeTg9yhfoMcSr                                       Gabbar Singh
# 32  7eJXTAO0qIPduGIE4Pqk5C                                             Parugu
# 33  13J2XQOZo0I8ZAufTXFvyd       Darling (Original Motion Picture Soundtrack)
# 35  5pDP183RRSwga8C5XNtRCL                                          Gentleman
# 36  5qpZDTqwLtGVwWlSz8TcHV                                                LIE
# 38  0j9Vp2crMI3DB942oviGvc                                        Kumari 21 F
# 42  0jgL9SVtLAWxM3VNKaQyaC                                            Rabhasa
# 43  5GfSI5flSZJaNh0Gwq3l61                                            Mukunda
# 44  7n61GzJSBuZGrm8U1V9TLd  Yemaaya Chesave (Original Motion Picture Sound...
# 45  6nlrhHVOHgVohenouAbuje                                             Athadu
# 46  37evPVtdfVL0X4Sji9tQdu                                              Kushi
# 47  6o9ysd0MFQXd6g4eWtcvNq                                   Idharammayilatho
# 48  2aNP8WRBq1cUgP4hvblCVa                                         Manmadhudu
# 49  5qmlAvprLWH32VE6oi2Wpe                                             Premam
# 52  0ezsoNG85fJtdsyobZNu68       Valmiki (Original Motion Picture Soundtrack)
# 53  2FL2qOOkZz0JFtS2Fzazf4  Sarileru Neekevvaru - A Tribute To The Indian ...
# 54  7APxU4HUrwGON54JHXoDx4                                              Ruler
# 55  0y35Kd8IAWamg1qsAg6mpA                                          Aswathama
# 56  0SVBhjxNR6eCoN1eN93A9h            Oo… Baava… (From "Prati Roju Pandaage")
# 57  1mZYQfcWj83VOe1v7wpYMr                                              Saaho
# 58  19kRwbWwLuNJduIg7G7mnt  ABCD - American Born Confused Desi (Original M...
# 60  2ANEQWadCAxBHp3Wr9b6aZ                                       Okka Kshanam
#
#    release_date  total_tracks  \
# 0    2011-04-09             6
# 1    2019-04-26            18
# 2    2013-01-05             7
# 3    2009-10-30             8
# 4    2019-05-04            15
# 5    2015-03-15             8
# 6    2011-03-18             9
# 7    2017-06-30             6
# 8    2015-12-21             5
# 9    2013-07-19             7
# 10   2008-02-28             9
# 11   2017-05-28             1
# 12   2018-06-25             1
# 13   2016-11-09             4
# 14   2020-01-20             6
# 15   2012-02-03             6
# 16   2017-05-22             5
# 18   2019-03-19            15
# 19   2011-12-22             6
# 20   2018-10-01             8
# 21   2017-11-07             6
# 23   2019-03-25            15
# 25   2017-06-12             1
# 26   2017-12-02             5
# 28   2017-01-12             5
# 29   2015-07-18             6
# 30   2006-04-08             6
# 31   2012-04-15             6
# 32   2008-04-05             6
# 33   2010-04-13             6
# 35   2016-05-20             5
# 36   2017-06-12             4
# 38   2015-10-31             5
# 42   2014-08-01             5
# 43   2014-12-03             7
# 44   2010-01-29             7
# 45          NaT             6
# 46   2001-03-27             6
# 47   2013-04-28             6
# 48          NaT             6
# 49   2016-08-18             7
# 52   2019-09-12             3
# 53   2019-08-16             1
# 54   2019-12-01             4
# 55   2019-12-19             1
# 56   2019-11-18             1
# 57   2019-08-28             4
# 58   2019-06-01             5
# 60   2017-12-22             3
#
#                                                   url
# 0   https://open.spotify.com/album/3rpmVMH5kV6jYkz...
# 1   https://open.spotify.com/album/6LDkuQZTLwRVja4...
# 2   https://open.spotify.com/album/0U9GjYJr2K1CK8t...
# 3   https://open.spotify.com/album/7vuWNVdv7zSwgHJ...
# 4   https://open.spotify.com/album/7pv1g7oSCc9aT7n...
# 5   https://open.spotify.com/album/0nJiWxWeUSYUq3x...
# 6   https://open.spotify.com/album/33thvrIEnv8XgCj...
# 7   https://open.spotify.com/album/2OPvJhDyy9YvHJT...
# 8   https://open.spotify.com/album/1pE2RYH3lcDdLpM...
# 9   https://open.spotify.com/album/4rjF7pEttnd3hME...
# 10  https://open.spotify.com/album/4TmtWuheIr8ejxI...
# 11  https://open.spotify.com/album/1md4f58fUAJK3Uo...
# 12  https://open.spotify.com/album/0OI4KhEq8LdWa33...
# 13  https://open.spotify.com/album/2mutIulE85wKAHr...
# 14  https://open.spotify.com/album/2wRphkgnlcGKkJI...
# 15  https://open.spotify.com/album/2OgVFYem1WFhNgO...
# 16  https://open.spotify.com/album/1kGnuSqFejTLaDJ...
# 18  https://open.spotify.com/album/5B8AmuHx5y2pKQW...
# 19  https://open.spotify.com/album/1AdvHtbDQU2lOcS...
# 20  https://open.spotify.com/album/35CCKYAkZ8GHzIb...
# 21  https://open.spotify.com/album/6RsL60SSZTVwigj...
# 23  https://open.spotify.com/album/4l1UZrzOz1la6gc...
# 25  https://open.spotify.com/album/6KVZ6Feu2G6bY1e...
# 26  https://open.spotify.com/album/4OM6femr6U4dYJw...
# 28  https://open.spotify.com/album/7D1e4SHtUU145PY...
# 29  https://open.spotify.com/album/6n7uqqX5fHZEoBX...
# 30  https://open.spotify.com/album/4CO4EDT6CLK1TC6...
# 31  https://open.spotify.com/album/57x6HaiiJdeTg9y...
# 32  https://open.spotify.com/album/7eJXTAO0qIPduGI...
# 33  https://open.spotify.com/album/13J2XQOZo0I8ZAu...
# 35  https://open.spotify.com/album/5pDP183RRSwga8C...
# 36  https://open.spotify.com/album/5qpZDTqwLtGVwWl...
# 38  https://open.spotify.com/album/0j9Vp2crMI3DB94...
# 42  https://open.spotify.com/album/0jgL9SVtLAWxM3V...
# 43  https://open.spotify.com/album/5GfSI5flSZJaNh0...
# 44  https://open.spotify.com/album/7n61GzJSBuZGrm8...
# 45  https://open.spotify.com/album/6nlrhHVOHgVohen...
# 46  https://open.spotify.com/album/37evPVtdfVL0X4S...
# 47  https://open.spotify.com/album/6o9ysd0MFQXd6g4...
# 48  https://open.spotify.com/album/2aNP8WRBq1cUgP4...
# 49  https://open.spotify.com/album/5qmlAvprLWH32VE...
# 52  https://open.spotify.com/album/0ezsoNG85fJtdsy...
# 53  https://open.spotify.com/album/2FL2qOOkZz0JFtS...
# 54  https://open.spotify.com/album/7APxU4HUrwGON54...
# 55  https://open.spotify.com/album/0y35Kd8IAWamg1q...
# 56  https://open.spotify.com/album/0SVBhjxNR6eCoN1...
# 57  https://open.spotify.com/album/1mZYQfcWj83VOe1...
# 58  https://open.spotify.com/album/19kRwbWwLuNJduI...
# 60  https://open.spotify.com/album/2ANEQWadCAxBHp3...

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      61 non-null     object
#  1   song_name    61 non-null     object
#  2   duration_ms  61 non-null     int64
#  3   url          61 non-null     object
#  4   popularity   61 non-null     int64
#  5   song_added   61 non-null     datetime64[ns, UTC]
#  6   album_id     61 non-null     object
#  7   artist_id    61 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.9+ KB
